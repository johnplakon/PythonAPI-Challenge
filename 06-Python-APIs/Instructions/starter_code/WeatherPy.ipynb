# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy as owm
import random
import seaborn as sns
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create settings dictionary with information we're interested in
settings = {"units": "imperial", "appid": api_key}

# Initialize data frame to store data from API calls
WeatherPy_df =pd.DataFrame(columns = ["City","Cloudiness", "Country",
                                    "Date", "Max Temp", "Wind Speed", 
                                    "Lat","Lng", "Humidity"])
count = 1 # counter to count the number of calls to API
err = 0 # error count to record how many cities the API responds back with no data.
sets = 0 # counter to count the number of call sets
index = 0 # index for the data frame WeatherPy data frame
#Get current time
t0 =time.time()
print(f'Beginning Data Retrieval \n ........................')
for city in cities:
    try:
        city1 = city.replace(" ", "%20") # remove space in city name so the URL retrieved is not broken.
        print(f'Processing Record {count} of Set {sets} | {city}' )
        print(f'{owm.BASE_URL}weather?q={city1}&units=imperial&APPID={api_key}')
        city_stats = owm.get_current(city, **settings)
        WeatherPy_df.set_value(index, "City", city_stats["name"])
        WeatherPy_df.set_value(index, "Cloudiness", city_stats("clouds.all"))
        WeatherPy_df.set_value(index, "Country", city_stats("sys.country"))
        WeatherPy_df.set_value(index, "Date", city_stats("dt"))
        WeatherPy_df.set_value(index, "Max Temp", city_stats("main.temp_max"))
        WeatherPy_df.set_value(index, "Wind Speed", city_stats("wind.speed"))
        WeatherPy_df.set_value(index, "Lat", city_stats("coord.lat"))
        WeatherPy_df.set_value(index, "Lng", city_stats("coord.lon"))
        WeatherPy_df.set_value(index, "Humidity", city_stats("main.humidity"))
        index = index +1 
    except Exception as e:
        print(e)
        err= err+1
    count = count+1
    if count == 51: # loop to limit 50 API calls per minute. The OpenWeatherMap API limit is 60 calls/min
        t1=time.time()
        count = 1 
        sets = sets+1
        time.sleep(60-(t1-t0))
        t0=time.time()

print("end of stats loop")
print(f'Could not get data for {err} cities')
# Out:
# Beginning Data Retrieval
#  ........................
# Processing Record 1 of Set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# C:\Users\jplakon\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\jplakon\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\jplakon\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\jplakon\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\jplakon\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\jplakon\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\jplakon\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\jplakon\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\jplakon\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record 2 of Set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 3 of Set 0 | hue
# http://api.openweathermap.org/data/2.5/weather?q=hue&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 4 of Set 0 | makat
# http://api.openweathermap.org/data/2.5/weather?q=makat&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 5 of Set 0 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 6 of Set 0 | bethel
# http://api.openweathermap.org/data/2.5/weather?q=bethel&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 7 of Set 0 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?q=vestmanna&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 8 of Set 0 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 9 of Set 0 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 10 of Set 0 | hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 11 of Set 0 | castro
# http://api.openweathermap.org/data/2.5/weather?q=castro&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 12 of Set 0 | el tigre
# http://api.openweathermap.org/data/2.5/weather?q=el%20tigre&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 13 of Set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 14 of Set 0 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 15 of Set 0 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?q=ostrovnoy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 16 of Set 0 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?q=okhotsk&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 17 of Set 0 | esperance
# http://api.openweathermap.org/data/2.5/weather?q=esperance&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 18 of Set 0 | porto walter
# http://api.openweathermap.org/data/2.5/weather?q=porto%20walter&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 19 of Set 0 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20ayora&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 20 of Set 0 | butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 21 of Set 0 | tura
# http://api.openweathermap.org/data/2.5/weather?q=tura&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 22 of Set 0 | bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 23 of Set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 24 of Set 0 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?q=sao%20filipe&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 25 of Set 0 | portland
# http://api.openweathermap.org/data/2.5/weather?q=portland&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 26 of Set 0 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 27 of Set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta%20arenas&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 28 of Set 0 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 29 of Set 0 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 30 of Set 0 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape%20town&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 31 of Set 0 | san andres
# http://api.openweathermap.org/data/2.5/weather?q=san%20andres&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 32 of Set 0 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira%20grande&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 33 of Set 0 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?q=attawapiskat&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 34 of Set 0 | alofi
# http://api.openweathermap.org/data/2.5/weather?q=alofi&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 35 of Set 0 | atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 36 of Set 0 | verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?q=verkhnyaya%20inta&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 37 of Set 0 | goundam
# http://api.openweathermap.org/data/2.5/weather?q=goundam&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 38 of Set 0 | bam
# http://api.openweathermap.org/data/2.5/weather?q=bam&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 39 of Set 0 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?q=ponta%20delgada&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 40 of Set 0 | sakakah
# http://api.openweathermap.org/data/2.5/weather?q=sakakah&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 41 of Set 0 | georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 42 of Set 0 | gao
# http://api.openweathermap.org/data/2.5/weather?q=gao&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 43 of Set 0 | shelburne
# http://api.openweathermap.org/data/2.5/weather?q=shelburne&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 44 of Set 0 | sabha
# http://api.openweathermap.org/data/2.5/weather?q=sabha&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 45 of Set 0 | vostok
# http://api.openweathermap.org/data/2.5/weather?q=vostok&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 46 of Set 0 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new%20norfolk&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 47 of Set 0 | emerald
# http://api.openweathermap.org/data/2.5/weather?q=emerald&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 48 of Set 0 | gudermes
# http://api.openweathermap.org/data/2.5/weather?q=gudermes&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 49 of Set 0 | vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 50 of Set 0 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?q=saint-pierre&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 1 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 2 of Set 1 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?q=vaitupu&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 3 of Set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 4 of Set 1 | lorengau
# http://api.openweathermap.org/data/2.5/weather?q=lorengau&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 5 of Set 1 | fundulea
# http://api.openweathermap.org/data/2.5/weather?q=fundulea&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 6 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 7 of Set 1 | ucluelet
# http://api.openweathermap.org/data/2.5/weather?q=ucluelet&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 8 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 9 of Set 1 | zhob
# http://api.openweathermap.org/data/2.5/weather?q=zhob&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 10 of Set 1 | lompoc
# http://api.openweathermap.org/data/2.5/weather?q=lompoc&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 11 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 12 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 13 of Set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 14 of Set 1 | husavik
# http://api.openweathermap.org/data/2.5/weather?q=husavik&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 15 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 16 of Set 1 | san angelo
# http://api.openweathermap.org/data/2.5/weather?q=san%20angelo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 17 of Set 1 | paamiut
# http://api.openweathermap.org/data/2.5/weather?q=paamiut&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 18 of Set 1 | vitina
# http://api.openweathermap.org/data/2.5/weather?q=vitina&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 19 of Set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 20 of Set 1 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?q=beringovskiy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 21 of Set 1 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?q=fairbanks&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 22 of Set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port%20elizabeth&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 23 of Set 1 | touros
# http://api.openweathermap.org/data/2.5/weather?q=touros&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 24 of Set 1 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?q=kamenskoye&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 25 of Set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?q=hasaki&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 26 of Set 1 | kochi
# http://api.openweathermap.org/data/2.5/weather?q=kochi&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 27 of Set 1 | melo
# http://api.openweathermap.org/data/2.5/weather?q=melo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 28 of Set 1 | dingle
# http://api.openweathermap.org/data/2.5/weather?q=dingle&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 29 of Set 1 | kazalinsk
# http://api.openweathermap.org/data/2.5/weather?q=kazalinsk&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 30 of Set 1 | chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 31 of Set 1 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 32 of Set 1 | goderich
# http://api.openweathermap.org/data/2.5/weather?q=goderich&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 33 of Set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?q=vila%20franca%20do%20campo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 34 of Set 1 | najran
# http://api.openweathermap.org/data/2.5/weather?q=najran&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 35 of Set 1 | constitucion
# http://api.openweathermap.org/data/2.5/weather?q=constitucion&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 36 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?q=east%20london&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 37 of Set 1 | butembo
# http://api.openweathermap.org/data/2.5/weather?q=butembo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 38 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 39 of Set 1 | yusva
# http://api.openweathermap.org/data/2.5/weather?q=yusva&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 40 of Set 1 | fortuna
# http://api.openweathermap.org/data/2.5/weather?q=fortuna&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 41 of Set 1 | clyde river
# http://api.openweathermap.org/data/2.5/weather?q=clyde%20river&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 42 of Set 1 | auki
# http://api.openweathermap.org/data/2.5/weather?q=auki&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 43 of Set 1 | tongchuan
# http://api.openweathermap.org/data/2.5/weather?q=tongchuan&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 44 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 45 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 46 of Set 1 | yanan
# http://api.openweathermap.org/data/2.5/weather?q=yanan&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 47 of Set 1 | puqi
# http://api.openweathermap.org/data/2.5/weather?q=puqi&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 48 of Set 1 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?q=cap%20malheureux&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 49 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar%20del%20plata&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 50 of Set 1 | barbar
# http://api.openweathermap.org/data/2.5/weather?q=barbar&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 1 of Set 2 | marawi
# http://api.openweathermap.org/data/2.5/weather?q=marawi&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 2 of Set 2 | paita
# http://api.openweathermap.org/data/2.5/weather?q=paita&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 3 of Set 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial%20do%20cabo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 4 of Set 2 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 5 of Set 2 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?q=yar-sale&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 6 of Set 2 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 7 of Set 2 | san jose
# http://api.openweathermap.org/data/2.5/weather?q=san%20jose&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 8 of Set 2 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?q=mahibadhoo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 9 of Set 2 | provideniya
# http://api.openweathermap.org/data/2.5/weather?q=provideniya&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 10 of Set 2 | moissala
# http://api.openweathermap.org/data/2.5/weather?q=moissala&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 11 of Set 2 | knysna
# http://api.openweathermap.org/data/2.5/weather?q=knysna&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 12 of Set 2 | fuxin
# http://api.openweathermap.org/data/2.5/weather?q=fuxin&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 13 of Set 2 | swan river
# http://api.openweathermap.org/data/2.5/weather?q=swan%20river&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 14 of Set 2 | cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 15 of Set 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 16 of Set 2 | plouzane
# http://api.openweathermap.org/data/2.5/weather?q=plouzane&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 17 of Set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?q=pevek&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 18 of Set 2 | upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 19 of Set 2 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?q=yenagoa&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 20 of Set 2 | salalah
# http://api.openweathermap.org/data/2.5/weather?q=salalah&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 21 of Set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 22 of Set 2 | jining
# http://api.openweathermap.org/data/2.5/weather?q=jining&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 23 of Set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 24 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 25 of Set 2 | beyla
# http://api.openweathermap.org/data/2.5/weather?q=beyla&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 26 of Set 2 | samalaeulu
# http://api.openweathermap.org/data/2.5/weather?q=samalaeulu&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 27 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 28 of Set 2 | muisne
# http://api.openweathermap.org/data/2.5/weather?q=muisne&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 29 of Set 2 | nibe
# http://api.openweathermap.org/data/2.5/weather?q=nibe&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 30 of Set 2 | talladega
# http://api.openweathermap.org/data/2.5/weather?q=talladega&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 31 of Set 2 | teguise
# http://api.openweathermap.org/data/2.5/weather?q=teguise&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 32 of Set 2 | victor harbor
# http://api.openweathermap.org/data/2.5/weather?q=victor%20harbor&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 33 of Set 2 | darnah
# http://api.openweathermap.org/data/2.5/weather?q=darnah&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 34 of Set 2 | soissons
# http://api.openweathermap.org/data/2.5/weather?q=soissons&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 35 of Set 2 | maputo
# http://api.openweathermap.org/data/2.5/weather?q=maputo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 36 of Set 2 | manaure
# http://api.openweathermap.org/data/2.5/weather?q=manaure&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 37 of Set 2 | cayenne
# http://api.openweathermap.org/data/2.5/weather?q=cayenne&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 38 of Set 2 | waipawa
# http://api.openweathermap.org/data/2.5/weather?q=waipawa&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 39 of Set 2 | ancud
# http://api.openweathermap.org/data/2.5/weather?q=ancud&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 40 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?q=saint%20george&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 41 of Set 2 | nishihara
# http://api.openweathermap.org/data/2.5/weather?q=nishihara&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 42 of Set 2 | kidal
# http://api.openweathermap.org/data/2.5/weather?q=kidal&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 43 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port%20alfred&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 44 of Set 2 | vostochnyy
# http://api.openweathermap.org/data/2.5/weather?q=vostochnyy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 45 of Set 2 | ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?q=ulaanbaatar&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 46 of Set 2 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 47 of Set 2 | westport
# http://api.openweathermap.org/data/2.5/weather?q=westport&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 48 of Set 2 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 49 of Set 2 | praya
# http://api.openweathermap.org/data/2.5/weather?q=praya&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 50 of Set 2 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 1 of Set 3 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 2 of Set 3 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?q=petropavlovsk-kamchatskiy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 3 of Set 3 | mentok
# http://api.openweathermap.org/data/2.5/weather?q=mentok&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 4 of Set 3 | amderma
# http://api.openweathermap.org/data/2.5/weather?q=amderma&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 5 of Set 3 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?q=mount%20gambier&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 6 of Set 3 | atasu
# http://api.openweathermap.org/data/2.5/weather?q=atasu&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 7 of Set 3 | jieshi
# http://api.openweathermap.org/data/2.5/weather?q=jieshi&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 8 of Set 3 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?q=santa%20rosa&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 9 of Set 3 | palu
# http://api.openweathermap.org/data/2.5/weather?q=palu&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 10 of Set 3 | abbeville
# http://api.openweathermap.org/data/2.5/weather?q=abbeville&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 11 of Set 3 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?q=lavrentiya&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 12 of Set 3 | sume
# http://api.openweathermap.org/data/2.5/weather?q=sume&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 13 of Set 3 | takoradi
# http://api.openweathermap.org/data/2.5/weather?q=takoradi&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 14 of Set 3 | madisonville
# http://api.openweathermap.org/data/2.5/weather?q=madisonville&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 15 of Set 3 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?q=kavaratti&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 16 of Set 3 | moree
# http://api.openweathermap.org/data/2.5/weather?q=moree&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 17 of Set 3 | hay river
# http://api.openweathermap.org/data/2.5/weather?q=hay%20river&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 18 of Set 3 | victoria
# http://api.openweathermap.org/data/2.5/weather?q=victoria&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 19 of Set 3 | hovd
# http://api.openweathermap.org/data/2.5/weather?q=hovd&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 20 of Set 3 | saint joseph
# http://api.openweathermap.org/data/2.5/weather?q=saint%20joseph&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 21 of Set 3 | souillac
# http://api.openweathermap.org/data/2.5/weather?q=souillac&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 22 of Set 3 | surovikino
# http://api.openweathermap.org/data/2.5/weather?q=surovikino&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 23 of Set 3 | dungarvan
# http://api.openweathermap.org/data/2.5/weather?q=dungarvan&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 24 of Set 3 | bugasong
# http://api.openweathermap.org/data/2.5/weather?q=bugasong&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 25 of Set 3 | asau
# http://api.openweathermap.org/data/2.5/weather?q=asau&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 26 of Set 3 | morgan city
# http://api.openweathermap.org/data/2.5/weather?q=morgan%20city&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 27 of Set 3 | bossangoa
# http://api.openweathermap.org/data/2.5/weather?q=bossangoa&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 28 of Set 3 | williams lake
# http://api.openweathermap.org/data/2.5/weather?q=williams%20lake&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 29 of Set 3 | wawa
# http://api.openweathermap.org/data/2.5/weather?q=wawa&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 30 of Set 3 | tondano
# http://api.openweathermap.org/data/2.5/weather?q=tondano&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 31 of Set 3 | dong hoi
# http://api.openweathermap.org/data/2.5/weather?q=dong%20hoi&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 32 of Set 3 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya%20guba&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 33 of Set 3 | balakhninskiy
# http://api.openweathermap.org/data/2.5/weather?q=balakhninskiy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 34 of Set 3 | yomou
# http://api.openweathermap.org/data/2.5/weather?q=yomou&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 35 of Set 3 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?q=pacific%20grove&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 36 of Set 3 | torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 37 of Set 3 | karaton
# http://api.openweathermap.org/data/2.5/weather?q=karaton&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 38 of Set 3 | karamea
# http://api.openweathermap.org/data/2.5/weather?q=karamea&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 39 of Set 3 | mulchen
# http://api.openweathermap.org/data/2.5/weather?q=mulchen&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 40 of Set 3 | trstena
# http://api.openweathermap.org/data/2.5/weather?q=trstena&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 41 of Set 3 | wuwei
# http://api.openweathermap.org/data/2.5/weather?q=wuwei&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 42 of Set 3 | puerto madryn
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20madryn&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 43 of Set 3 | castanos
# http://api.openweathermap.org/data/2.5/weather?q=castanos&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 44 of Set 3 | tabou
# http://api.openweathermap.org/data/2.5/weather?q=tabou&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 45 of Set 3 | tabuk
# http://api.openweathermap.org/data/2.5/weather?q=tabuk&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 46 of Set 3 | bakchar
# http://api.openweathermap.org/data/2.5/weather?q=bakchar&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 47 of Set 3 | kahului
# http://api.openweathermap.org/data/2.5/weather?q=kahului&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 48 of Set 3 | ig
# http://api.openweathermap.org/data/2.5/weather?q=ig&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 49 of Set 3 | belmonte
# http://api.openweathermap.org/data/2.5/weather?q=belmonte&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 50 of Set 3 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?q=krasnoselkup&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 1 of Set 4 | banepa
# http://api.openweathermap.org/data/2.5/weather?q=banepa&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 2 of Set 4 | kracheh
# http://api.openweathermap.org/data/2.5/weather?q=kracheh&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 3 of Set 4 | marsa matruh
# http://api.openweathermap.org/data/2.5/weather?q=marsa%20matruh&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 4 of Set 4 | skagen
# http://api.openweathermap.org/data/2.5/weather?q=skagen&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 5 of Set 4 | ostersund
# http://api.openweathermap.org/data/2.5/weather?q=ostersund&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 6 of Set 4 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?q=tumannyy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 7 of Set 4 | weinan
# http://api.openweathermap.org/data/2.5/weather?q=weinan&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 8 of Set 4 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 9 of Set 4 | nuuk
# http://api.openweathermap.org/data/2.5/weather?q=nuuk&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 10 of Set 4 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?q=kulhudhuffushi&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 11 of Set 4 | energetik
# http://api.openweathermap.org/data/2.5/weather?q=energetik&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 12 of Set 4 | sitka
# http://api.openweathermap.org/data/2.5/weather?q=sitka&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 13 of Set 4 | itarema
# http://api.openweathermap.org/data/2.5/weather?q=itarema&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 14 of Set 4 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?q=olafsvik&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 15 of Set 4 | porto novo
# http://api.openweathermap.org/data/2.5/weather?q=porto%20novo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 16 of Set 4 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?q=san%20cristobal&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 17 of Set 4 | la ronge
# http://api.openweathermap.org/data/2.5/weather?q=la%20ronge&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 18 of Set 4 | johi
# http://api.openweathermap.org/data/2.5/weather?q=johi&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 19 of Set 4 | temaraia
# http://api.openweathermap.org/data/2.5/weather?q=temaraia&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 20 of Set 4 | port moresby
# http://api.openweathermap.org/data/2.5/weather?q=port%20moresby&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 21 of Set 4 | russell
# http://api.openweathermap.org/data/2.5/weather?q=russell&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 22 of Set 4 | fojnica
# http://api.openweathermap.org/data/2.5/weather?q=fojnica&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 23 of Set 4 | vila velha
# http://api.openweathermap.org/data/2.5/weather?q=vila%20velha&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 24 of Set 4 | pincher creek
# http://api.openweathermap.org/data/2.5/weather?q=pincher%20creek&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 25 of Set 4 | thunder bay
# http://api.openweathermap.org/data/2.5/weather?q=thunder%20bay&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 26 of Set 4 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?q=kangaatsiaq&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 27 of Set 4 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?q=chokurdakh&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 28 of Set 4 | samusu
# http://api.openweathermap.org/data/2.5/weather?q=samusu&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 29 of Set 4 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?q=los%20llanos%20de%20aridane&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 30 of Set 4 | krasnovishersk
# http://api.openweathermap.org/data/2.5/weather?q=krasnovishersk&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 31 of Set 4 | hargeysa
# http://api.openweathermap.org/data/2.5/weather?q=hargeysa&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 32 of Set 4 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?q=quatre%20cocos&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 33 of Set 4 | beloha
# http://api.openweathermap.org/data/2.5/weather?q=beloha&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 34 of Set 4 | axim
# http://api.openweathermap.org/data/2.5/weather?q=axim&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 35 of Set 4 | shache
# http://api.openweathermap.org/data/2.5/weather?q=shache&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 36 of Set 4 | cravo norte
# http://api.openweathermap.org/data/2.5/weather?q=cravo%20norte&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 37 of Set 4 | zavitinsk
# http://api.openweathermap.org/data/2.5/weather?q=zavitinsk&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 38 of Set 4 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?q=komsomolskiy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 39 of Set 4 | beipiao
# http://api.openweathermap.org/data/2.5/weather?q=beipiao&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 40 of Set 4 | humenne
# http://api.openweathermap.org/data/2.5/weather?q=humenne&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 41 of Set 4 | andenes
# http://api.openweathermap.org/data/2.5/weather?q=andenes&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 42 of Set 4 | faanui
# http://api.openweathermap.org/data/2.5/weather?q=faanui&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 43 of Set 4 | dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?q=dhidhdhoo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 44 of Set 4 | paucartambo
# http://api.openweathermap.org/data/2.5/weather?q=paucartambo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 45 of Set 4 | burica
# http://api.openweathermap.org/data/2.5/weather?q=burica&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 46 of Set 4 | santa isabel do rio negro
# http://api.openweathermap.org/data/2.5/weather?q=santa%20isabel%20do%20rio%20negro&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 47 of Set 4 | apache junction
# http://api.openweathermap.org/data/2.5/weather?q=apache%20junction&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 48 of Set 4 | ruatoria
# http://api.openweathermap.org/data/2.5/weather?q=ruatoria&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 49 of Set 4 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?q=iqaluit&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 50 of Set 4 | mehamn
# http://api.openweathermap.org/data/2.5/weather?q=mehamn&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 1 of Set 5 | avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 2 of Set 5 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 3 of Set 5 | todos santos
# http://api.openweathermap.org/data/2.5/weather?q=todos%20santos&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 4 of Set 5 | pastos bons
# http://api.openweathermap.org/data/2.5/weather?q=pastos%20bons&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 5 of Set 5 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 6 of Set 5 | kasane
# http://api.openweathermap.org/data/2.5/weather?q=kasane&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 7 of Set 5 | balkhash
# http://api.openweathermap.org/data/2.5/weather?q=balkhash&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 8 of Set 5 | moissac
# http://api.openweathermap.org/data/2.5/weather?q=moissac&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 9 of Set 5 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 10 of Set 5 | podor
# http://api.openweathermap.org/data/2.5/weather?q=podor&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 11 of Set 5 | uyar
# http://api.openweathermap.org/data/2.5/weather?q=uyar&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 12 of Set 5 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?q=louisbourg&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 13 of Set 5 | derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?q=derzhavinsk&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 14 of Set 5 | sola
# http://api.openweathermap.org/data/2.5/weather?q=sola&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 15 of Set 5 | dalbandin
# http://api.openweathermap.org/data/2.5/weather?q=dalbandin&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 16 of Set 5 | vallenar
# http://api.openweathermap.org/data/2.5/weather?q=vallenar&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 17 of Set 5 | karaul
# http://api.openweathermap.org/data/2.5/weather?q=karaul&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 18 of Set 5 | azad shahr
# http://api.openweathermap.org/data/2.5/weather?q=azad%20shahr&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 19 of Set 5 | xichang
# http://api.openweathermap.org/data/2.5/weather?q=xichang&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 20 of Set 5 | colares
# http://api.openweathermap.org/data/2.5/weather?q=colares&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 21 of Set 5 | beaverlodge
# http://api.openweathermap.org/data/2.5/weather?q=beaverlodge&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 22 of Set 5 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?q=sobolevo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 23 of Set 5 | ballina
# http://api.openweathermap.org/data/2.5/weather?q=ballina&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 24 of Set 5 | monrovia
# http://api.openweathermap.org/data/2.5/weather?q=monrovia&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 25 of Set 5 | miyako
# http://api.openweathermap.org/data/2.5/weather?q=miyako&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 26 of Set 5 | airai
# http://api.openweathermap.org/data/2.5/weather?q=airai&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 27 of Set 5 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?q=mys%20shmidta&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 28 of Set 5 | beyneu
# http://api.openweathermap.org/data/2.5/weather?q=beyneu&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 29 of Set 5 | hunchun
# http://api.openweathermap.org/data/2.5/weather?q=hunchun&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 30 of Set 5 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous%20virieux&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 31 of Set 5 | opuwo
# http://api.openweathermap.org/data/2.5/weather?q=opuwo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 32 of Set 5 | oriximina
# http://api.openweathermap.org/data/2.5/weather?q=oriximina&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 33 of Set 5 | aklavik
# http://api.openweathermap.org/data/2.5/weather?q=aklavik&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 34 of Set 5 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?q=mandalgovi&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 35 of Set 5 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?q=abu%20samrah&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 36 of Set 5 | sechura
# http://api.openweathermap.org/data/2.5/weather?q=sechura&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 37 of Set 5 | sorland
# http://api.openweathermap.org/data/2.5/weather?q=sorland&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 38 of Set 5 | bundaberg
# http://api.openweathermap.org/data/2.5/weather?q=bundaberg&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 39 of Set 5 | kushima
# http://api.openweathermap.org/data/2.5/weather?q=kushima&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 40 of Set 5 | pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?q=pangkalanbuun&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 41 of Set 5 | saldanha
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 42 of Set 5 | unity
# http://api.openweathermap.org/data/2.5/weather?q=unity&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 43 of Set 5 | chumikan
# http://api.openweathermap.org/data/2.5/weather?q=chumikan&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 44 of Set 5 | saint-denis
# http://api.openweathermap.org/data/2.5/weather?q=saint-denis&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 45 of Set 5 | clermont
# ...
# Processing Record 42 of Set 9 | nurota
# http://api.openweathermap.org/data/2.5/weather?q=nurota&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 43 of Set 9 | port hedland
# http://api.openweathermap.org/data/2.5/weather?q=port%20hedland&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 44 of Set 9 | puerto madero
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20madero&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 45 of Set 9 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?q=saint-georges&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 46 of Set 9 | karangasem
# http://api.openweathermap.org/data/2.5/weather?q=karangasem&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 47 of Set 9 | te anau
# http://api.openweathermap.org/data/2.5/weather?q=te%20anau&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 48 of Set 9 | barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 49 of Set 9 | okha
# http://api.openweathermap.org/data/2.5/weather?q=okha&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 50 of Set 9 | los alamos
# http://api.openweathermap.org/data/2.5/weather?q=los%20alamos&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 1 of Set 10 | grand forks
# http://api.openweathermap.org/data/2.5/weather?q=grand%20forks&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 2 of Set 10 | aksarayskiy
# http://api.openweathermap.org/data/2.5/weather?q=aksarayskiy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 3 of Set 10 | pedernales
# http://api.openweathermap.org/data/2.5/weather?q=pedernales&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 4 of Set 10 | jiddah
# http://api.openweathermap.org/data/2.5/weather?q=jiddah&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 5 of Set 10 | nome
# http://api.openweathermap.org/data/2.5/weather?q=nome&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 6 of Set 10 | wad madani
# http://api.openweathermap.org/data/2.5/weather?q=wad%20madani&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 7 of Set 10 | lumajang
# http://api.openweathermap.org/data/2.5/weather?q=lumajang&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 8 of Set 10 | la palma
# http://api.openweathermap.org/data/2.5/weather?q=la%20palma&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 9 of Set 10 | tutoia
# http://api.openweathermap.org/data/2.5/weather?q=tutoia&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 10 of Set 10 | sao joaquim
# http://api.openweathermap.org/data/2.5/weather?q=sao%20joaquim&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 11 of Set 10 | ilhabela
# http://api.openweathermap.org/data/2.5/weather?q=ilhabela&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 12 of Set 10 | dzhusaly
# http://api.openweathermap.org/data/2.5/weather?q=dzhusaly&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 13 of Set 10 | karpathos
# http://api.openweathermap.org/data/2.5/weather?q=karpathos&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 14 of Set 10 | khao yoi
# http://api.openweathermap.org/data/2.5/weather?q=khao%20yoi&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 15 of Set 10 | zamora
# http://api.openweathermap.org/data/2.5/weather?q=zamora&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 16 of Set 10 | garowe
# http://api.openweathermap.org/data/2.5/weather?q=garowe&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 17 of Set 10 | santa rosalia
# http://api.openweathermap.org/data/2.5/weather?q=santa%20rosalia&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 18 of Set 10 | tezu
# http://api.openweathermap.org/data/2.5/weather?q=tezu&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 19 of Set 10 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 20 of Set 10 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?q=banda%20aceh&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 21 of Set 10 | ariquemes
# http://api.openweathermap.org/data/2.5/weather?q=ariquemes&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 22 of Set 10 | kalanguy
# http://api.openweathermap.org/data/2.5/weather?q=kalanguy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 23 of Set 10 | phan rang
# http://api.openweathermap.org/data/2.5/weather?q=phan%20rang&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 24 of Set 10 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 25 of Set 10 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?q=keti%20bandar&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 26 of Set 10 | abalak
# http://api.openweathermap.org/data/2.5/weather?q=abalak&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 27 of Set 10 | chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?q=chernyshevskiy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 28 of Set 10 | tete
# http://api.openweathermap.org/data/2.5/weather?q=tete&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 29 of Set 10 | salo
# http://api.openweathermap.org/data/2.5/weather?q=salo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 30 of Set 10 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20escondido&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 31 of Set 10 | khasan
# http://api.openweathermap.org/data/2.5/weather?q=khasan&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 32 of Set 10 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?q=ishigaki&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 33 of Set 10 | havoysund
# http://api.openweathermap.org/data/2.5/weather?q=havoysund&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 34 of Set 10 | menongue
# http://api.openweathermap.org/data/2.5/weather?q=menongue&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 35 of Set 10 | rangapara
# http://api.openweathermap.org/data/2.5/weather?q=rangapara&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 36 of Set 10 | laguna
# http://api.openweathermap.org/data/2.5/weather?q=laguna&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 37 of Set 10 | vao
# http://api.openweathermap.org/data/2.5/weather?q=vao&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 38 of Set 10 | goragorskiy
# http://api.openweathermap.org/data/2.5/weather?q=goragorskiy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 39 of Set 10 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?q=ambilobe&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 40 of Set 10 | lolua
# http://api.openweathermap.org/data/2.5/weather?q=lolua&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 41 of Set 10 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?q=makakilo%20city&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 42 of Set 10 | andover
# http://api.openweathermap.org/data/2.5/weather?q=andover&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 43 of Set 10 | morehead
# http://api.openweathermap.org/data/2.5/weather?q=morehead&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 44 of Set 10 | borzya
# http://api.openweathermap.org/data/2.5/weather?q=borzya&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 45 of Set 10 | bonavista
# http://api.openweathermap.org/data/2.5/weather?q=bonavista&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 46 of Set 10 | suluq
# http://api.openweathermap.org/data/2.5/weather?q=suluq&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 47 of Set 10 | champerico
# http://api.openweathermap.org/data/2.5/weather?q=champerico&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 48 of Set 10 | tarudant
# http://api.openweathermap.org/data/2.5/weather?q=tarudant&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 49 of Set 10 | de aar
# http://api.openweathermap.org/data/2.5/weather?q=de%20aar&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 50 of Set 10 | tonstad
# http://api.openweathermap.org/data/2.5/weather?q=tonstad&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 1 of Set 11 | manaus
# http://api.openweathermap.org/data/2.5/weather?q=manaus&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 2 of Set 11 | ukiah
# http://api.openweathermap.org/data/2.5/weather?q=ukiah&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 3 of Set 11 | indian head
# http://api.openweathermap.org/data/2.5/weather?q=indian%20head&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 4 of Set 11 | homestead
# http://api.openweathermap.org/data/2.5/weather?q=homestead&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 5 of Set 11 | necochea
# http://api.openweathermap.org/data/2.5/weather?q=necochea&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 6 of Set 11 | rio grande
# http://api.openweathermap.org/data/2.5/weather?q=rio%20grande&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 7 of Set 11 | hvolsvollur
# http://api.openweathermap.org/data/2.5/weather?q=hvolsvollur&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 8 of Set 11 | margate
# http://api.openweathermap.org/data/2.5/weather?q=margate&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 9 of Set 11 | jinchang
# http://api.openweathermap.org/data/2.5/weather?q=jinchang&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 10 of Set 11 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?q=zhigansk&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 11 of Set 11 | bogorodskoye
# http://api.openweathermap.org/data/2.5/weather?q=bogorodskoye&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 12 of Set 11 | ipora
# http://api.openweathermap.org/data/2.5/weather?q=ipora&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 13 of Set 11 | saint-leu
# http://api.openweathermap.org/data/2.5/weather?q=saint-leu&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 14 of Set 11 | biu
# http://api.openweathermap.org/data/2.5/weather?q=biu&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 15 of Set 11 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?q=nhulunbuy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 16 of Set 11 | bela
# http://api.openweathermap.org/data/2.5/weather?q=bela&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 17 of Set 11 | manuk mangkaw
# http://api.openweathermap.org/data/2.5/weather?q=manuk%20mangkaw&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 18 of Set 11 | roberval
# http://api.openweathermap.org/data/2.5/weather?q=roberval&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 19 of Set 11 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?q=cabo%20san%20lucas&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 20 of Set 11 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?q=deputatskiy&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 21 of Set 11 | marquette
# http://api.openweathermap.org/data/2.5/weather?q=marquette&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 22 of Set 11 | manakara
# http://api.openweathermap.org/data/2.5/weather?q=manakara&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 23 of Set 11 | tabas
# http://api.openweathermap.org/data/2.5/weather?q=tabas&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 24 of Set 11 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?q=saint-francois&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 25 of Set 11 | bang saphan
# http://api.openweathermap.org/data/2.5/weather?q=bang%20saphan&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 26 of Set 11 | sibolga
# http://api.openweathermap.org/data/2.5/weather?q=sibolga&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 27 of Set 11 | tamiahua
# http://api.openweathermap.org/data/2.5/weather?q=tamiahua&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 28 of Set 11 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?q=havre-saint-pierre&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 29 of Set 11 | eyl
# http://api.openweathermap.org/data/2.5/weather?q=eyl&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 30 of Set 11 | danielskuil
# http://api.openweathermap.org/data/2.5/weather?q=danielskuil&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 31 of Set 11 | bur gabo
# http://api.openweathermap.org/data/2.5/weather?q=bur%20gabo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# HTTP Error 404: Not Found
# Processing Record 32 of Set 11 | carauari
# http://api.openweathermap.org/data/2.5/weather?q=carauari&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 33 of Set 11 | khandagayty
# http://api.openweathermap.org/data/2.5/weather?q=khandagayty&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 34 of Set 11 | kuusamo
# http://api.openweathermap.org/data/2.5/weather?q=kuusamo&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 35 of Set 11 | tautira
# http://api.openweathermap.org/data/2.5/weather?q=tautira&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 36 of Set 11 | rodino
# http://api.openweathermap.org/data/2.5/weather?q=rodino&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 37 of Set 11 | henties bay
# http://api.openweathermap.org/data/2.5/weather?q=henties%20bay&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 38 of Set 11 | tahe
# http://api.openweathermap.org/data/2.5/weather?q=tahe&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 39 of Set 11 | imbituba
# http://api.openweathermap.org/data/2.5/weather?q=imbituba&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 40 of Set 11 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?q=ugoofaaru&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 41 of Set 11 | tiangua
# http://api.openweathermap.org/data/2.5/weather?q=tiangua&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# Processing Record 42 of Set 11 | nagato
# http://api.openweathermap.org/data/2.5/weather?q=nagato&units=imperial&APPID=922cbef6b5531cf2690b4bd8a04410f3
# end of stats loop
# Could not get data for 70 cities

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
WeatherPy_df.count()
# Out:
# City          522
# Cloudiness    522
# Country       522
# Date          522
# Max Temp      522
# Wind Speed    522
# Lat           522
# Lng           522
# Humidity      522
# dtype: int64

# %%
WeatherPy_df.to_csv("WeatherPy.csv", encoding='utf-8', index=False)
WeatherPy_df.head(10)
# Out:
#           City Cloudiness Country        Date Max Temp Wind Speed    Lat  \
# 0      Ushuaia         40      AR  1562988307     39.2       6.93 -54.81
# 1      Rikitea         62      PF  1562988184    74.42      14.14 -23.12
# 2          Hue         20      VN  1562988309     98.6       8.05  16.47
# 3        Makat         51      KZ  1562988310       80      16.28  47.65
# 4  Pangnirtung         92      CA  1562988311    42.92       1.16  66.15
# 5       Bethel         90      US  1562988133     66.2      11.41  60.79
# 6    Vestmanna        100      FO  1562988313       50        4.7  62.16
# 7      Qaanaaq        100      GL  1562988313    43.64       6.67  77.48
# 8  Yellowknife         75      CA  1562988314     57.2      11.41  62.45
# 9         Hilo         20      US  1562988025     84.2      10.29  19.71
#
#       Lng Humidity
# 0  -68.31       80
# 1 -134.97       78
# 2  107.58       44
# 3   53.35       57
# 4  -65.72       86
# 5 -161.76       63
# 6   -7.17      100
# 7  -69.36       64
# 8 -114.38       47
# 9 -155.08       54

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(10,8))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Max Temp"], color='r', alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temperature ({datetime.now().date()})')
plt.savefig("LatVsTemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,6))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Humidity"], color='blue', alpha=0.5)
plt.ylim(10,120)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity ({datetime.now().date()})')
plt.savefig("LatVsHumidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(8,6))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Cloudiness"], color='green', alpha=0.5)

plt.ylim(-20,(WeatherPy_df["Cloudiness"].max()+10))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness ({datetime.now().date()})')
plt.savefig("LatVsCloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(8,6))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Wind Speed"], color='orange', alpha=0.5)

plt.ylim((WeatherPy_df["Wind Speed"].min()-5),(WeatherPy_df["Wind Speed"].max()+5))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed ({datetime.now().date()})')
plt.savefig("LatVsWind.png")
plt.show()
